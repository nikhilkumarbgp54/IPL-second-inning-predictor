# %% [markdown]
# # Import required libraries for this project

# %%
import pandas as pd
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import set_config
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # Now import deliveries and matches dataset from file manager

# %%
M=pd.read_csv('matches.csv')
D=pd.read_csv('deliveries.csv')

# %% [markdown]
# # Now print match dataset in table

# %%
M.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Now print deliveries dataset in table

# %%
D.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# # Find the number of rows and columns in match dataset

# %%
M.shape
# Out:
# (756, 18)

# %% [markdown]
# # Find the number of rows and colums in deliveries dataset

# %%
D.shape
# Out:
# (179078, 21)

# %% [markdown]
# # Requirement of dataset in the form of batting team, bowling team, city, runs left, balls left, wickets left, total runs, current run rate, required run rate and results

# %%
Ts=D.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
Ts
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
Ts=Ts[Ts['inning']==1]

# %%
M_new=M.merge(Ts[['match_id','total_runs']],left_on='id',right_on='match_id')
M_new
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
M_new['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams=[
     'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
M_new['team1'] = M_new['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
M_new['team2'] = M_new['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

M_new['team1'] = M_new['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
M_new['team2'] = M_new['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
M_new = M_new[M_new['team1'].isin(teams)]
M_new = M_new[M_new['team2'].isin(teams)]

# %%
M_new = M_new[M_new['dl_applied'] == 0]

# %%
M_new = M_new[['match_id','city','winner','total_runs']]

# %%
D_new = M_new.merge(D,on='match_id')

# %%
D_new = D_new[D_new['inning'] == 2]
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating current score using cumulative sum of total_runs_y

# %%
D_new['current_score'] = D_new.groupby('match_id').cumsum()['total_runs_y']
D_new['total_runs_x']=D_new['total_runs_x']+1
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating runs left = winnig runs - current score

# %%
D_new['runs_left'] = D_new['total_runs_x'] - D_new['current_score']
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating balls left = 120 -  (over x 6 + ball)

# %%
D_new['balls_left'] = 126 - (D_new['over']*6 + D_new['ball'])
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating the wickets left before calculating we need to convert NaN value to integer 0 and string value to 1

# %%
D_new['player_dismissed'] = D_new['player_dismissed'].fillna("0")
D_new['player_dismissed'] = D_new['player_dismissed'].apply(lambda x:x if x == "0" else "1")
D_new['player_dismissed'] = D_new['player_dismissed'].astype('int')
wickets_left = D_new.groupby('match_id').cumsum()['player_dismissed'].values
D_new['wickets_left'] = 10 - wickets_left
D_new.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           208       2
# 126         1  Hyderabad  Sunrisers Hyderabad           208       2
# 127         1  Hyderabad  Sunrisers Hyderabad           208       2
# 128         1  Hyderabad  Sunrisers Hyderabad           208       2
# 129         1  Hyderabad  Sunrisers Hyderabad           208       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# ...

# %% [markdown]
# # Now calculating current run rate = runs/overs

# %%
D_new['crr'] = (D_new['current_score']*6)/(120 - D_new['balls_left'])
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating required run rate = runs left / overs left

# %%
D_new['rrr'] = (D_new['runs_left']*6)/D_new['balls_left']
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now calculating results make a function in this way that if batting team = winner then output would be 1, otherwise 0

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
D_new['result'] = D_new.apply(result,axis=1)
D_new
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           208       2
# 126            1  Hyderabad  Sunrisers Hyderabad           208       2
# 127            1  Hyderabad  Sunrisers Hyderabad           208       2
# 128            1  Hyderabad  Sunrisers Hyderabad           208       2
# 129            1  Hyderabad  Sunrisers Hyderabad           208       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           153       2
# 149574     11415  Hyderabad       Mumbai Indians           153       2
# 149575     11415  Hyderabad       Mumbai Indians           153       2
# 149576     11415  Hyderabad       Mumbai Indians           153       2
# 149577     11415  Hyderabad       Mumbai Indians           153       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# # Now printing final dataset with reuired features that we need for prediction

# %%
final = D_new[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr','result']]
final
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 125           207         119            10           208  6.000000
# ...

# %% [markdown]
# # Now sampling is required

# %%
final = final.sample(final.shape[0])

# %%
final.sample()
# Out:
#           batting_team                 bowling_team       city  runs_left  \
# 66207  Kings XI Punjab  Royal Challengers Bangalore  Bangalore          7
#
#        balls_left  wickets_left  total_runs_x       crr       rrr  result
# 66207          13             6           159  8.523364  3.230769       1

# %% [markdown]
# # Now we need to remove the infinity term from required run rate. only the one zero that will create trouble which comes after last ball

# %%
final.dropna(inplace=True)

# %%
final = final[final['balls_left'] != 0]
final.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final
# Out:
#                        batting_team         bowling_team          city  \
# 18220              Delhi Daredevils       Mumbai Indians         Delhi
# 30088               Kings XI Punjab     Delhi Daredevils  Bloemfontein
# 91744                Mumbai Indians      Kings XI Punjab        Mumbai
# 148307              Kings XI Punjab  Chennai Super Kings        Mohali
# 128186             Delhi Daredevils  Chennai Super Kings          Pune
# ...                             ...                  ...           ...
# 120408             Delhi Daredevils  Sunrisers Hyderabad        Raipur
# 92186   Royal Challengers Bangalore  Sunrisers Hyderabad     Bangalore
# 72951              Delhi Daredevils     Rajasthan Royals         Delhi
# 138426               Delhi Capitals      Kings XI Punjab        Mohali
# 77134   Royal Challengers Bangalore     Rajasthan Royals     Bangalore
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# ...

# %% [markdown]
# # Now import train and test split method from sklearn library for trainig and testing the dataset.

# %%
X = final.iloc[:,:-1]
y = final.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 84019                Mumbai Indians          Sunrisers Hyderabad      Mumbai
# 47095   Royal Challengers Bangalore               Mumbai Indians      Mumbai
# 108063             Rajasthan Royals               Mumbai Indians      Mumbai
# 125506  Royal Challengers Bangalore             Delhi Daredevils   Bengaluru
# 97839                Mumbai Indians              Kings XI Punjab  Chandigarh
# ...                             ...                          ...         ...
# 106493              Kings XI Punjab          Chennai Super Kings     Chennai
# 92486         Kolkata Knight Riders             Rajasthan Royals   Ahmedabad
# 13617           Chennai Super Kings             Delhi Daredevils       Delhi
# 49214                Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 14007              Rajasthan Royals              Deccan Chargers      Jaipur
#
# ...

# %%
X_test
# Out:
#                        batting_team                 bowling_team  \
# 44189              Rajasthan Royals               Mumbai Indians
# 130368              Kings XI Punjab             Rajasthan Royals
# 103411             Delhi Daredevils              Kings XI Punjab
# 134708             Rajasthan Royals        Kolkata Knight Riders
# 68396         Kolkata Knight Riders               Mumbai Indians
# ...                             ...                          ...
# 96169              Delhi Daredevils             Rajasthan Royals
# 17018              Delhi Daredevils  Royal Challengers Bangalore
# 28163   Royal Challengers Bangalore               Mumbai Indians
# 147374          Sunrisers Hyderabad               Mumbai Indians
# 30041               Kings XI Punjab             Delhi Daredevils
#
#                   city  runs_left  balls_left  wickets_left  total_runs_x  \
# 44189           Jaipur        135          77             6           175
# ...

# %%
y_train
# Out:
# 84019     1
# 47095     0
# 108063    0
# 125506    1
# 97839     1
#          ..
# 106493    0
# 92486     0
# 13617     1
# 49214     1
# 14007     1
# Name: result, Length: 57073, dtype: int64

# %%
y_test
# Out:
# 44189     0
# 130368    0
# 103411    1
# 134708    0
# 68396     0
#          ..
# 96169     0
# 17018     1
# 28163     0
# 147374    0
# 30041     1
# Name: result, Length: 14269, dtype: int64

# %% [markdown]
# # Now apply column transformer and onehot encoder for catagorical column

# %%
trf=ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %% [markdown]
# # Now creating pipe line for assembling the steps

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8060831172471792

# %%
set_config(display='diagram')

# %%
pipe.predict_proba(X_test)[10]
# Out:
# array([0.22198111, 0.77801889])

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
D_new['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))
